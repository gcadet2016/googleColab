# %% [markdown]
# <a href="https://colab.research.google.com/github/gcadet2016/googleColab/blob/data%2FimportCsv/Import_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello world friends')
# Out:
# Hello world

# %% [markdown]
# # load external files
#
# 1- upload file from my laptop to google colab <br>
# 2- upload file to github <br>
# 3- upload from my google drive <br>

# %%
import pandas as pd
from google.colab import files

# 1- upload file to google colab
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cb077dad-2039-43ec-8f76-2a3bfd731fb7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cb077dad-2039-43ec-8f76-2a3bfd731fb7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# download from colab
import io

df = pd.read_csv(io.BytesIO(uploaded['locations.csv']), sep='\t')
df.head()
# Out:
#    id                                               name    north    south  \
# 0   1             Albion, Mendocino Co., California, USA  39.2408  39.2153
# 1   2          Burbank, Los Angeles Co., California, USA  34.2217  34.1424
# 2   3  Mitrula Marsh, Tahoe National Forest, Sierra C...  39.6272  39.6226
# 3   4  Salt Point State Park, Sonoma Co., California,...  38.5923  38.5584
# 4   5            Gualala, Mendocino Co., California, USA  38.7868  38.7597
#
#       east     west   high    low
# 0 -123.738 -123.778  100.0    0.0
# 1 -118.280 -118.370  294.0  148.0
# 2 -120.614 -120.620    NaN    NaN
# 3 -123.283 -123.343  100.0    0.0
# 4 -123.519 -123.557  100.0    0.0

# %%
# 2- download from gitHub

url = 'copied_raw_github_link'
df = pd.read_csv(url)

# %%
# 3- download form my google drive
from google.colab import drive

drive.mount('/content/drive')
lien_images = '/content/drive/MyDrive/Colab_Notebooks/csv/images.csv'
df_images = pd.read_csv(lien_images, sep='\t', index_col = 'id')

df_images.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    content_type copyright_holder                                     license  \
# id
# 1    image/jpeg    Nathan Wilson  Creative Commons Wikipedia Compatible v3.0
# 2    image/jpeg    Nathan Wilson  Creative Commons Wikipedia Compatible v3.0
# 3    image/jpeg    Nathan Wilson  Creative Commons Wikipedia Compatible v3.0
# 4    image/jpeg    Nathan Wilson  Creative Commons Wikipedia Compatible v3.0
# 5    image/jpeg    Nathan Wilson  Creative Commons Wikipedia Compatible v3.0
#
#     ok_for_export  diagnostic
# id
# 1               1           1
# 2               1           1
# 3               1           1
# 4               1           1
# 5               1           1
